# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = 40
from copy import deepcopy

# %%
# !ls "raw data"
# Out:
# ACC HS Chronic Absenteeism.xlsx
# ACC HS Core and Weighted Performance.csv
# ACC HS Core and Weighted Performance.xlsx
# ACC HS Graduation Rate.xlsx
# Annual Regents Exams.xlsx
# GRAD_RATE_AND_OUTCOMES_2022.csv
# nys_annualregents_score.csv

# %%
# annual graduation data by cohort and subgroup 
data = pd.read_csv("raw data/GRAD_RATE_AND_OUTCOMES_2022.csv",index_col=False,dtype='string')

# %%
data.columns
# Out:
# Index(['report_school_year', 'aggregation_index', 'aggregation_type',
#        'aggregation_code', 'aggregation_name', 'lea_beds', 'lea_name',
#        'nrc_code', 'nrc_desc', 'county_code', 'county_name', 'nyc_ind',
#        'boces_code', 'boces_name', 'membership_code', 'membership_key',
#        'membership_desc', 'subgroup_code', 'subgroup_name', 'enroll_cnt',
#        'grad_cnt', 'grad_pct', 'local_cnt', 'local_pct', 'reg_cnt', 'reg_pct',
#        'reg_adv_cnt', 'reg_adv_pct', 'non_diploma_credential_cnt',
#        'non_diploma_credential_pct', 'still_enr_cnt', 'still_enr_pct',
#        'ged_cnt', 'ged_pct', 'dropout_cnt', 'dropout_pct'],
#       dtype='object')

# %%
data.head(1)
# Out:
#   report_school_year aggregation_index aggregation_type aggregation_code  \
# 0            2021-22                 0        Statewide     000000000000
#
#              aggregation_name lea_beds lea_name nrc_code nrc_desc county_code  \
# 0  All Districts and Charters     <NA>     <NA>     <NA>     <NA>        <NA>
#
#   county_name nyc_ind boces_code boces_name membership_code membership_key  \
# 0        <NA>    <NA>       <NA>       <NA>               6            180
#
#                       membership_desc subgroup_code subgroup_name enroll_cnt  \
# 0  2016 Total Cohort - 6 Year Outcome            01  All Students     207157
#
#   grad_cnt grad_pct local_cnt local_pct reg_cnt reg_pct reg_adv_cnt  \
# 0   183454      89%      6212        3%   96334     47%       80908
#
#   reg_adv_pct non_diploma_credential_cnt non_diploma_credential_pct  \
# 0         39%                       2058                         1%
#
#   still_enr_cnt still_enr_pct ged_cnt ged_pct dropout_cnt dropout_pct
# 0          4664            2%    1746      1%       15088          7%

# %%
data.membership_desc.unique().tolist()
# Out:
# ['2016 Total Cohort - 6 Year Outcome',
#  '2017 Total Cohort - 5 Year Outcome',
#  '2018 Total Cohort - 4 Year Outcome',
#  '2017 Total Cohort - 5 Year Outcome - August 2022',
#  '2018 Total Cohort - 4 Year Outcome - August 2022',
#  '2016 Total Cohort - 6 Year Outcome - August 2022']

# %%
data.nrc_desc.unique().tolist()
# Out:
# ['Urban-Suburban High Needs',
#  'Charters',
#  'Average Needs',
#  'Low Needs',
#  'Rural High Needs',
#  'Buffalo  Rochester  Yonkers  Syracuse',
#  'NYC']

# %%
copy_3 = data.loc[:,["aggregation_code","aggregation_name","county_name","nrc_desc","membership_desc","subgroup_name","grad_cnt",
           "grad_pct"]]

# %%
# transforming our assessment data 
data.columns = data.columns.str.lower()
data = data[data.aggregation_type == 'School']
data.loc[:,["aggregation_code","aggregation_name","county_name","nrc_desc","membership_desc","subgroup_name","grad_cnt"]]
#data = data[data.subgroup_name != 'All Students']
#nys_assessment_df = nys_assessment_df[nys_assessment_df.subject != 'Combined']
#nys_assessment_df = nys_assessment_df.reset_index(drop=True)
#data
# Out:
#        aggregation_code                  aggregation_name county_name  \
# 81831      010100010034                ALBANY HIGH SCHOOL      ALBANY
# 81832      010100010034                ALBANY HIGH SCHOOL      ALBANY
# 81833      010100010034                ALBANY HIGH SCHOOL      ALBANY
# 81834      010100010034                ALBANY HIGH SCHOOL      ALBANY
# 81835      010100010034                ALBANY HIGH SCHOOL      ALBANY
# ...                 ...                               ...         ...
# 221861     680801040001  DUNDEE JUNIOR-SENIOR HIGH SCHOOL       YATES
# 221862     680801040001  DUNDEE JUNIOR-SENIOR HIGH SCHOOL       YATES
# 221863     680801040001  DUNDEE JUNIOR-SENIOR HIGH SCHOOL       YATES
# 221864     680801040001  DUNDEE JUNIOR-SENIOR HIGH SCHOOL       YATES
# 221865     680801040001  DUNDEE JUNIOR-SENIOR HIGH SCHOOL       YATES
#
#                          nrc_desc  \
# 81831   Urban-Suburban High Needs
# 81832   Urban-Suburban High Needs
# 81833   Urban-Suburban High Needs
# 81834   Urban-Suburban High Needs
# 81835   Urban-Suburban High Needs
# ...                           ...
# 221861           Rural High Needs
# 221862           Rural High Needs
# 221863           Rural High Needs
# 221864           Rural High Needs
# 221865           Rural High Needs
#
#                                          membership_desc  \
# 81831                 2016 Total Cohort - 6 Year Outcome
# 81832                 2016 Total Cohort - 6 Year Outcome
# 81833                 2016 Total Cohort - 6 Year Outcome
# 81834                 2016 Total Cohort - 6 Year Outcome
# 81835                 2016 Total Cohort - 6 Year Outcome
# ...                                                  ...
# 221861  2016 Total Cohort - 6 Year Outcome - August 2022
# 221862  2016 Total Cohort - 6 Year Outcome - August 2022
# 221863  2016 Total Cohort - 6 Year Outcome - August 2022
# 221864  2016 Total Cohort - 6 Year Outcome - August 2022
# 221865  2016 Total Cohort - 6 Year Outcome - August 2022
#
#                            subgroup_name grad_cnt
# 81831                               Male      254
# 81832                             Female      295
# 81833         General Education Students      501
# 81834         Students with Disabilities       48
# 81835   American Indian or Alaska Native        -
# ...                                  ...      ...
# 221861                Not in Foster Care       30
# 221862                          Homeless        -
# 221863                      Not Homeless        -
# 221864                       Not Migrant       30
# 221865        Parent Not in Armed Forces       30
#
# [132282 rows x 7 columns]

# %% [markdown]
# ### Reading in Datasets

# %%
nys_absenteeism_df = pd.read_excel("raw data/ACC HS Chronic Absenteeism.xlsx",index_col=False, 
                                   dtype=({'ENTITY_CD':'string'}))

# %%
nys_annual_regents = pd.read_csv("raw data/nys_annualregents_score.csv",index_col=False,
                                dtype=({'ENTITY_CD':'string','INSTITUTION_ID':'string'}))

# %%
# reformating column names and entity names 
nys_annual_regents.columns = nys_annual_regents.columns.str.lower()
nys_annual_regents.entity_name = nys_annual_regents.entity_name.str.title()

# removing aggregated measurements and district entities
nys_annual_regents = nys_annual_regents[~nys_annual_regents['entity_cd'].astype('str').str.endswith('0000')]
nys_annual_regents = nys_annual_regents[~nys_annual_regents['entity_cd'].astype('str').str.endswith('111111111111')]
nys_annual_regents = nys_annual_regents[~nys_annual_regents['entity_cd'].astype('str').str.endswith('000000000001')]
nys_annual_regents = nys_annual_regents[~nys_annual_regents['entity_cd'].astype('str').str.endswith('000000000002')]
nys_annual_regents = nys_annual_regents[~nys_annual_regents['entity_cd'].astype('str').str.endswith('000000000003')]
nys_annual_regents = nys_annual_regents[~nys_annual_regents['entity_cd'].astype('str').str.endswith('000000000004')]
nys_annual_regents = nys_annual_regents[~nys_annual_regents['entity_cd'].astype('str').str.endswith('000000000005')]
nys_annual_regents = nys_annual_regents[~nys_annual_regents['entity_cd'].astype('str').str.endswith('000000000006')]
nys_annual_regents = nys_annual_regents[~nys_annual_regents['entity_cd'].astype('str').str.endswith('000000000007')]

# %%
ann_regs_cols = ['entity_cd','entity_name','year','subject','subgroup_name',
                 'tested','num_prof']

# %%
nys_annual_regents = nys_annual_regents.loc[:,ann_regs_cols]
nys_annual_regents = nys_annual_regents[(nys_annual_regents.year == 2022) 
                                        & (nys_annual_regents.subgroup_name != 'All Students')]

# %%
nys_annual_regents
# Out:
#            entity_cd                       entity_name  year  \
# 381971  010100010030   William S Hackett Middle School  2022
# 381972  010100010030   William S Hackett Middle School  2022
# 381973  010100010030   William S Hackett Middle School  2022
# 381974  010100010030   William S Hackett Middle School  2022
# 381975  010100010030   William S Hackett Middle School  2022
# ...              ...                               ...   ...
# 748975  680801040001  Dundee Junior-Senior High School  2022
# 748976  680801040001  Dundee Junior-Senior High School  2022
# 748977  680801040001  Dundee Junior-Senior High School  2022
# 748978  680801040001  Dundee Junior-Senior High School  2022
# 748979  680801040001  Dundee Junior-Senior High School  2022
#
#                               subject  \
# 381971  Regents Common Core Algebra I
# 381972     Regents Living Environment
# 381973  Regents Common Core Algebra I
# 381974     Regents Living Environment
# 381975  Regents Common Core Algebra I
# ...                               ...
# 748975     Regents Living Environment
# 748976      Regents NF Global History
# 748977      Regents Phy Set/Chemistry
# 748978      Regents Phy Set/Earth Sci
# 748979  Regents Common Core Algebra I
#
#                                           subgroup_name  tested num_prof
# 381971  Asian or Native Hawaiian/Other Pacific Islander      17       14
# 381972  Asian or Native Hawaiian/Other Pacific Islander      14       14
# 381973                        Black or African American      10        s
# 381974                        Black or African American      13        s
# 381975                       Economically Disadvantaged      23       20
# ...                                                 ...     ...      ...
# 748975                                            White      37       32
# 748976                                            White      34        s
# 748977                                            White      11        5
# 748978                                            White      27        s
# 748979                                            White      30        s
#
# [234125 rows x 7 columns]

# %%
#nys_assessment_df = pd.read_csv("raw data/ACC HS Core and Weighted Performance.csv",index_col=False,
#                                dtype=({"ENTITY_CD":"string"}))

# %%
nys_grad_rate_df = pd.read_excel("raw data/ACC HS Graduation Rate.xlsx",index_col=False,dtype=({'ENTITY_CD':'string'}))

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# Based on the documentation,

# %%
# transforming our assessment data 
#nys_assessment_df.columns = nys_assessment_df.columns.str.lower()
#nys_assessment_df = nys_assessment_df.loc[:,['entity_cd', 'entity_name','year','subject','subgroup_name','weighted_index']]
#nys_assessment_df = nys_assessment_df[~nys_assessment_df['entity_cd'].astype('str').str.endswith('0000')]
#nys_assessment_df = nys_assessment_df[nys_assessment_df.subgroup_name != 'All Students']
#nys_assessment_df = nys_assessment_df.reset_index(drop=True)
#nys_assessment_df.loc[:,['entity_cd', 'entity_name','year','subject','subgroup_name','weighted_index','wgt_level']]
#nys_assessment_df

# %%
# transforming our grad rate dataset 
nys_grad_rate_df.columns = nys_grad_rate_df.columns.str.lower()
nys_grad_rate_df = nys_grad_rate_df.loc[:,['entity_cd','entity_name','year','subgroup_name','cohort','grad_rate']]
nys_grad_rate_df = nys_grad_rate_df[~nys_grad_rate_df['entity_cd'].astype('str').str.endswith('0000')]
nys_grad_rate_df = nys_grad_rate_df[nys_grad_rate_df.subgroup_name != 'All Students']
nys_grad_rate_df = nys_grad_rate_df.reset_index(drop=True)

# %%
# transforming our chronic absenteeism dataset
nys_absenteeism_df.columns = nys_absenteeism_df.columns.str.lower()
nys_absenteeism_df = nys_absenteeism_df.loc[:,['entity_cd', 'entity_name','year','subgroup_name','absent_rate','level']]
nys_absenteeism_df = nys_absenteeism_df[~nys_absenteeism_df['entity_cd'].astype('str').str.endswith('0000')]
nys_absenteeism_df = nys_absenteeism_df[nys_absenteeism_df.subgroup_name != 'All Students']
nys_absenteeism_df.entity_name = nys_absenteeism_df.entity_name.str.title()
nys_absenteeism_df = nys_absenteeism_df.reset_index(drop=True)
nys_absenteeism_df
# Out:
#           entity_cd               entity_name  year  \
# 0      010100010034        Albany High School  2021
# 1      010100010034        Albany High School  2021
# 2      010100010034        Albany High School  2021
# 3      010100010034        Albany High School  2021
# 4      010100010034        Albany High School  2021
# ...             ...                       ...   ...
# 25086  680801040002  Dundee Elementary School  2022
# 25087  680801040002  Dundee Elementary School  2022
# 25088  680801040002  Dundee Elementary School  2022
# 25089  680801040002  Dundee Elementary School  2022
# 25090  680801040002  Dundee Elementary School  2022
#
#                                          subgroup_name absent_rate level
# 0                           Students with Disabilities        47.3   NaN
# 1                     American Indian or Alaska Native           s   NaN
# 2      Asian or Native Hawaiian/Other Pacific Islander        18.3   NaN
# 3                            Black or African American        44.6   NaN
# 4                                   Hispanic or Latino        38.4   NaN
# ...                                                ...         ...   ...
# 25086                               Hispanic or Latino           s     s
# 25087                                            White           s     s
# 25088                                      Multiracial           s     s
# 25089                       Economically Disadvantaged           s     s
# 25090                         English Language Learner           s     s
#
# [25091 rows x 6 columns]

# %%
nys_grad_rate_22 = nys_grad_rate_df[(nys_grad_rate_df.cohort == 'Combined') & (nys_grad_rate_df.year == 2022) 
                 & (nys_grad_rate_df.grad_rate != 's')]
nys_grad_rate_22 = nys_grad_rate_22.drop(columns=['cohort'])

# %%
nys_grad_rate_22.entity_name = nys_grad_rate_22.entity_name.str.title()

# %%
nys_grad_rate_22
# Out:
#           entity_cd                       entity_name  year  \
# 3      010100010034                Albany High School  2022
# 7      010100010034                Albany High School  2022
# 10     010100010034                Albany High School  2022
# 13     010100010034                Albany High School  2022
# 14     010100010034                Albany High School  2022
# ...             ...                               ...   ...
# 94838  671501040002         Warsaw Senior High School  2022
# 94862  680601060001                  Penn Yan Academy  2022
# 94874  680601060001                  Penn Yan Academy  2022
# 94897  680801040001  Dundee Junior-Senior High School  2022
# 94908  680801040001  Dundee Junior-Senior High School  2022
#
#                     subgroup_name grad_rate
# 3              Hispanic or Latino      73.7
# 7                           White      86.9
# 10                    Multiracial      77.4
# 13       English Language Learner      70.4
# 14     Economically Disadvantaged      75.5
# ...                           ...       ...
# 94838  Economically Disadvantaged      88.1
# 94862                       White      91.1
# 94874  Economically Disadvantaged      88.6
# 94897                       White      78.6
# 94908  Economically Disadvantaged      68.8
#
# [4689 rows x 5 columns]

# %%
shared_cols
# Out:
# ['entity_cd', 'entity_name', 'year', 'subgroup_name']

# %%
pd.merge(pd.merge(nys_annual_regents,nys_grad_rate_22,how='inner',on=shared_cols),nys_absenteeism_df,
        how='inner',on=shared_cols)
# Out:
#           entity_cd                       entity_name  year  \
# 0      010100010034                Albany High School  2022
# 1      010100010034                Albany High School  2022
# 2      010100010034                Albany High School  2022
# 3      010100010034                Albany High School  2022
# 4      010100010034                Albany High School  2022
# ...             ...                               ...   ...
# 42642  680801040001  Dundee Junior-Senior High School  2022
# 42643  680801040001  Dundee Junior-Senior High School  2022
# 42644  680801040001  Dundee Junior-Senior High School  2022
# 42645  680801040001  Dundee Junior-Senior High School  2022
# 42646  680801040001  Dundee Junior-Senior High School  2022
#
#                                     subject  \
# 0      Regents US History&Gov't (Framework)
# 1                   Regents Phy Set/Physics
# 2                 Regents Phy Set/Chemistry
# 3                 Regents NF Global History
# 4                Regents Living Environment
# ...                                     ...
# 42642            Regents Living Environment
# 42643             Regents NF Global History
# 42644             Regents Phy Set/Chemistry
# 42645             Regents Phy Set/Earth Sci
# 42646         Regents Common Core Algebra I
#
#                                          subgroup_name  tested num_prof  \
# 0      Asian or Native Hawaiian/Other Pacific Islander       0        0
# 1      Asian or Native Hawaiian/Other Pacific Islander      22        8
# 2      Asian or Native Hawaiian/Other Pacific Islander      37       18
# 3      Asian or Native Hawaiian/Other Pacific Islander      61       46
# 4      Asian or Native Hawaiian/Other Pacific Islander      40       22
# ...                                                ...     ...      ...
# 42642                                            White      37       32
# 42643                                            White      34        s
# 42644                                            White      11        5
# 42645                                            White      27        s
# 42646                                            White      30        s
#
#       grad_rate absent_rate level
# 0          82.4        41.8     2
# 1          82.4        41.8     2
# 2          82.4        41.8     2
# 3          82.4        41.8     2
# 4          82.4        41.8     2
# ...         ...         ...   ...
# 42642      78.6        35.1     3
# 42643      78.6        35.1     3
# 42644      78.6        35.1     3
# 42645      78.6        35.1     3
# 42646      78.6        35.1     3
#
# [42647 rows x 10 columns]

# %% [markdown]
# Now, we need to merge the two columns to have a total of 4 shared columns and 5 features, thus having 9 columns in our final dataframe

# %%
shared_cols = ['entity_cd','entity_name','year','subgroup_name']

# %%
copy_final_df =pd.merge(pd.merge(nys_absenteeism_df,nys_assessment_df, on = shared_cols),nys_grad_rate_df, on = shared_cols)

# %%
copy_final_df[copy_final_df.entity_name == 'ALBANY HIGH SCHOOL']
# Out:
#         entity_cd         entity_name  year               subgroup_name  \
# 0    010100010034  ALBANY HIGH SCHOOL  2022  Students with Disabilities
# 1    010100010034  ALBANY HIGH SCHOOL  2022  Students with Disabilities
# 2    010100010034  ALBANY HIGH SCHOOL  2022  Students with Disabilities
# 3    010100010034  ALBANY HIGH SCHOOL  2022  Students with Disabilities
# 4    010100010034  ALBANY HIGH SCHOOL  2022  Students with Disabilities
# ..            ...                 ...   ...                         ...
# 247  010100010034  ALBANY HIGH SCHOOL  2022    English Language Learner
# 248  010100010034  ALBANY HIGH SCHOOL  2022    English Language Learner
# 249  010100010034  ALBANY HIGH SCHOOL  2022    English Language Learner
# 250  010100010034  ALBANY HIGH SCHOOL  2022    English Language Learner
# 251  010100010034  ALBANY HIGH SCHOOL  2022    English Language Learner
#
#     enrollment absent_count  subject weighted_index  cohort cohort_count  \
# 0          422          272      ELA            5.8  4-Year           76
# 1          422          272      ELA            5.8  5-Year           90
# 2          422          272      ELA            5.8  6-Year           76
# 3          422          272     MATH           22.5  4-Year           76
# 4          422          272     MATH           22.5  5-Year           90
# ..         ...          ...      ...            ...     ...          ...
# 247        433          236  SCIENCE           83.6  5-Year          105
# 248        433          236  SCIENCE           83.6  6-Year           74
# 249        433          236   SOCIAL            3.3  4-Year           94
# 250        433          236   SOCIAL            3.3  5-Year          105
# 251        433          236   SOCIAL            3.3  6-Year           74
#
#     grad_count
# 0           47
# 1           48
# 2           45
# 3           47
# 4           48
# ..         ...
# 247         78
# 248         43
# 249         74
# 250         78
# 251         43
#
# [108 rows x 11 columns]

# %%
nys_final_df = pd.merge(nys_absenteeism_df,nys_grad_rate_df,how='inner',on=['entity_cd','entity_name','year','subgroup_name'])

# %%
# number of unique schools 
len(nys_final_df.entity_name.unique())
# Out:
# 1426

# %% [markdown]
# This dataset contains 1426 unique schools

# %%
nys_final_df
# Out:
#           entity_cd               entity_name  year  \
# 0      010100010034        ALBANY HIGH SCHOOL  2021
# 1      010100010034        ALBANY HIGH SCHOOL  2021
# 2      010100010034        ALBANY HIGH SCHOOL  2021
# 3      010100010034        ALBANY HIGH SCHOOL  2021
# 4      010100010034        ALBANY HIGH SCHOOL  2021
# ...             ...                       ...   ...
# 66280  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
# 66281  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
# 66282  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
# 66283  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
# 66284  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
#
#                           subgroup_name enrollment absent_count  cohort  \
# 0            Students with Disabilities        414          196  6-Year
# 1            Students with Disabilities        414          196  5-Year
# 2            Students with Disabilities        414          196  4-Year
# 3      American Indian or Alaska Native          9            s  6-Year
# 4      American Indian or Alaska Native          9            s  5-Year
# ...                                 ...        ...          ...     ...
# 66280        Economically Disadvantaged          s            s  5-Year
# 66281        Economically Disadvantaged          s            s  6-Year
# 66282          English Language Learner          s            s  4-Year
# 66283          English Language Learner          s            s  6-Year
# 66284          English Language Learner          s            s  5-Year
#
#       cohort_count grad_count
# 0               93         48
# 1               77         42
# 2               89         45
# 3                3          s
# 4                2          s
# ...            ...        ...
# 66280            0          s
# 66281            0          s
# 66282            0          s
# 66283            0          s
# 66284            0          s
#
# [66285 rows x 9 columns]

# %%
nys_final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66285 entries, 0 to 66284
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   entity_cd      66285 non-null  int64
#  1   entity_name    66285 non-null  object
#  2   year           66285 non-null  int64
#  3   subgroup_name  66285 non-null  object
#  4   enrollment     66285 non-null  object
#  5   absent_count   66285 non-null  object
#  6   cohort         66285 non-null  object
#  7   cohort_count   66285 non-null  object
#  8   grad_count     66285 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 5.1+ MB

# %%
nys_final_df = nys_final_df[nys_final_df.grad_count.str.contains('s')==False]
nys_final_df = nys_final_df[nys_final_df.absent_count.str.contains('s') == False]

# %%
nys_final_df
# Out:
#           entity_cd                       entity_name  year  \
# 0       10100010034                ALBANY HIGH SCHOOL  2021
# 1       10100010034                ALBANY HIGH SCHOOL  2021
# 2       10100010034                ALBANY HIGH SCHOOL  2021
# 6       10100010034                ALBANY HIGH SCHOOL  2021
# 7       10100010034                ALBANY HIGH SCHOOL  2021
# ...             ...                               ...   ...
# 66227  680601060001                  PENN YAN ACADEMY  2022
# 66246  680801040001  DUNDEE JUNIOR-SENIOR HIGH SCHOOL  2022
# 66247  680801040001  DUNDEE JUNIOR-SENIOR HIGH SCHOOL  2022
# 66248  680801040001  DUNDEE JUNIOR-SENIOR HIGH SCHOOL  2022
# 66252  680801040001  DUNDEE JUNIOR-SENIOR HIGH SCHOOL  2022
#
#                                          subgroup_name enrollment  \
# 0                           Students with Disabilities        414
# 1                           Students with Disabilities        414
# 2                           Students with Disabilities        414
# 6      Asian or Native Hawaiian/Other Pacific Islander        219
# 7      Asian or Native Hawaiian/Other Pacific Islander        219
# ...                                                ...        ...
# 66227                       Economically Disadvantaged        191
# 66246                                            White        174
# 66247                                            White        174
# 66248                                            White        174
# 66252                       Economically Disadvantaged        122
#
#       absent_count  cohort cohort_count grad_count
# 0              196  6-Year           93         48
# 1              196  5-Year           77         42
# 2              196  4-Year           89         45
# 6               40  4-Year           57         48
# 7               40  6-Year           53         44
# ...            ...     ...          ...        ...
# 66227           67  6-Year           65         58
# 66246           61  6-Year           54         46
# 66247           61  5-Year           40         30
# 66248           61  4-Year           53         40
# 66252           54  4-Year           32         22
#
# [24969 rows x 9 columns]

# %%
copy_1[copy_1.cohort == '6-Year']
# Out:
#        entity_cd         entity_name  year subgroup_name  cohort cohort_count  \
# 5   010100010034  ALBANY HIGH SCHOOL  2022         White  6-Year          139
# 54  010100010034  ALBANY HIGH SCHOOL  2021         White  6-Year          129
#
#    grad_count
# 5         125
# 54        101

# %%
copy_2[copy_2.membership_desc.str.contains('6')]
# Out:
#       aggregation_code    aggregation_name                   nrc_desc  \
# 81839     010100010034  ALBANY HIGH SCHOOL  Urban-Suburban High Needs
# 81948     010100010034  ALBANY HIGH SCHOOL  Urban-Suburban High Needs
#
#                                         membership_desc subgroup_name grad_cnt
# 81839                2016 Total Cohort - 6 Year Outcome         White      122
# 81948  2016 Total Cohort - 6 Year Outcome - August 2022         White      122

# %%
nys_grad_rate_df
# Out:
#           entity_cd               entity_name  year  \
# 0      010100010034        ALBANY HIGH SCHOOL  2022
# 1      010100010034        ALBANY HIGH SCHOOL  2022
# 2      010100010034        ALBANY HIGH SCHOOL  2022
# 3      010100010034        ALBANY HIGH SCHOOL  2022
# 4      010100010034        ALBANY HIGH SCHOOL  2022
# ...             ...                       ...   ...
# 71221  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
# 71222  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
# 71223  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
# 71224  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
# 71225  680801040002  DUNDEE ELEMENTARY SCHOOL  2022
#
#                                          subgroup_name  cohort grad_count
# 0                                   Hispanic or Latino  6-Year         82
# 1                             English Language Learner  4-Year         74
# 2                                          Multiracial  6-Year          s
# 3                                                White  4-Year        123
# 4                                                White  5-Year        122
# ...                                                ...     ...        ...
# 71221  Asian or Native Hawaiian/Other Pacific Islander  6-Year          s
# 71222                        Black or African American  4-Year          s
# 71223                        Black or African American  5-Year          s
# 71224                        Black or African American  6-Year          s
# 71225                       Students with Disabilities  6-Year          s
#
# [71226 rows x 6 columns]

# %% [markdown]
# ## Exporting Cleaned Data

# %%
#nys_grad_rate_22.to_csv('data/2022_NYS_grad-rate.csv',index=False)
